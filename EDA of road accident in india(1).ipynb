# %% [markdown]
# # Road Accident in india during 2001-2012

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data=pd.read_excel("datafile.xls")

# %%
data
# Out:
#               States  Year                     CAUSE  Male  Female  Total  \
# 0     ANDHRA PRADESH  2001  Truck/Lorry (Government)   103      26    129
# 1     ANDHRA PRADESH  2001     Truck/Lorry (Private)  2171     414   2585
# 2     ANDHRA PRADESH  2001          Bus (Government)   488     119    607
# 3     ANDHRA PRADESH  2001             Bus (Private)   289      76    365
# 4     ANDHRA PRADESH  2001   Tempo/Vans (Government)    13       3     16
# ...              ...   ...                       ...   ...     ...    ...
# 6295      PUDUCHERRY  2012             Three Wheeler     0       0      0
# 6296      PUDUCHERRY  2012               Two Wheeler    49      15     64
# 6297      PUDUCHERRY  2012                   Bicycle     0       0      0
# 6298      PUDUCHERRY  2012                Pedestrian     0       0      0
# 6299      PUDUCHERRY  2012   Others (Please Specify)    22       9     31
#
#             Lat       Long
# 0     14.750429  78.570026
# ...

# %%
data.describe()
# Out:
#               Year         Male       Female        Total          Lat  \
# count  6300.000000  6300.000000  6300.000000  6300.000000  6300.000000
# mean   2006.500000   176.779048    31.743810   208.522857    22.579335
# std       3.452327   392.862803    67.167001   455.365286     6.603272
# min    2001.000000     0.000000     0.000000     0.000000     8.900373
# 25%    2003.750000     1.000000     0.000000     1.000000    19.250232
# 50%    2006.500000    15.000000     3.000000    18.000000    23.800393
# 75%    2009.250000   149.000000    27.000000   175.000000    27.333330
# max    2012.000000  4022.000000   653.000000  4484.000000    34.299959
#
#               Long
# count  6300.000000
# mean     81.618272
# std       7.628217
# min      71.192400
# 25%      75.980003
# 50%      78.050006
# 75%      88.616647
# max      94.216667

# %%
# the dataset contains 6300 row and 8 columns
#the average male death count is 176 per year
#the average female death count is 31 per year

# %%
data.describe(include="object")
# Out:
#        States                  CAUSE
# count    6300                   6300
# unique     35                     15
# top     Delhi  Truck/Lorry (Private)
# freq      180                    420

# %%
data.nunique()
# Out:
# States      35
# Year        12
# CAUSE       15
# Male       990
# Female     342
# Total     1071
# Lat         35
# Long        34
# dtype: int64

# %%
#the dataset have the following details
# 15 kinds of causes are resion for the accidents

# %%
plt.rcParams["figure.figsize"]=(15,5)
new_dataframe = data[["Year","Male"]]
var = new_dataframe.groupby(['Year']).sum()
var.plot(kind='bar',stacked=False,grid=False)
plt.title("The Male death rate in a year wise",color="green",fontsize="25")
plt.xticks(rotation='vertical')
plt.ylabel("Number of Male death",fontsize="20")
plt.xlabel("Years",fontsize="20")

plt.show()

# %%
#More number of male accident occurs at 2010,2011 and 2012

# %%
plt.rcParams["figure.figsize"]=(15,5)
new_dataframe = data[["Year","Female"]]
var = new_dataframe.groupby(['Year']).sum()
var.plot(kind='bar',stacked=False,grid=False)
plt.title("The Female death rate in a year wise",color="green",fontsize="25")
plt.xticks(rotation='vertical')
plt.ylabel("Number of Female death",fontsize="20")
plt.xlabel("Years",fontsize="20")
plt.show()

# %%
#More number of female accident occurs at 2010,2011 and 2012

# %%
plt.rcParams["figure.figsize"]=(13,8)
df=data.groupby(["States"]).agg({"Total":sum}).head(20)
df.plot(kind='barh',stacked=False,grid=False)
plt.title("States Wise total death rate",color="green",fontsize="25")
plt.ylabel("States",fontsize="20")
plt.xlabel("Number of Deaths",fontsize="20")
plt.show()

# %%
#Highest  number of accident occurs at Andhra Pradesh

# %%
plt.rcParams["figure.figsize"]=(13,8)
df=data.groupby(["States"]).agg({"Male":sum}).head(20)
df.plot(kind='barh',stacked=False,grid=False)
plt.title("States Wise total Male death rate",color="green",fontsize="25")
plt.ylabel("States",fontsize="20")
plt.xlabel("Number of Deaths",fontsize="20")
plt.show()

# %%
#Highest  number of Male accident occurs at Andhra Pradesh

# %%
plt.rcParams["figure.figsize"]=(13,8)
df=data.groupby(["States"]).agg({"Female":sum}).head(20)
df.plot(kind='barh',stacked=False,grid=False)
plt.title("States Wise total Female death rate",color="green",fontsize="25")
plt.ylabel("States",fontsize="20")
plt.xlabel("Number of Deaths",fontsize="20")
plt.show()

# %%
#Highest  number of Female accident occurs at Andhra Pradesh

# %%
plt.rcParams["figure.figsize"]=(13,8)
cause=data.groupby(["CAUSE"]).agg({"Total":sum})
cause.plot(kind="barh",fontsize=10)
plt.title("Causes based death rate",color="green",fontsize="25")
plt.ylabel("Causes",fontsize="20")
plt.xlabel("Number of Deaths",fontsize="20")
plt.show()

# %%
#The maximum accidents are occurred by the truck/lorry(private)
#The second maximum accidents is occures by two-wheelers

# %%
plt.rcParams["figure.figsize"]=(13,8)
cause=data.groupby(["CAUSE"]).agg({"Male":sum})
cause.plot(kind="barh",fontsize=10)
plt.title("Causes based death rate",color="green",fontsize="25")
plt.ylabel("Causes",fontsize="20")
plt.xlabel("Number of Deaths",fontsize="20")
plt.show()

# %%
#the truck/lorry(private) is make maximum  male accidents
#the second maximum male accident is make by two wheelers

# %%
plt.rcParams["figure.figsize"]=(13,8)
cause=data.groupby(["CAUSE"]).agg({"Female":sum})
cause.plot(kind="barh",fontsize=10)
plt.title("Causes based death rate",color="green",fontsize="25")
plt.ylabel("Causes",fontsize="20")
plt.xlabel("Number of Deaths",fontsize="20")
plt.show()

# %%
#the truck/lorry(private) is make maximum female accidents
#the second maximum female accident is make by two wheelers

# %%
plt.rcParams["figure.figsize"]=(13,8)
new_dataframe = data[["Year","Male","Female"]]
var = new_dataframe.groupby(['Year']).sum()
var.plot(kind='bar',stacked=False,grid=False)
plt.title("Stacked Death Genderwise over the year",color="green",fontsize="25")
plt.ylabel("Number of Death rate",fontsize="20")
plt.xlabel("Year",fontsize="20")
plt.show()

# %%
#Every year number of female death rate is lower than the male death rate
#80% Male death rate is equal to 20% female death rate

# %%
plt.rcParams["figure.figsize"]=(13,8)
new_dataframe = data[["CAUSE","Male","Female"]]
var = new_dataframe.groupby(['CAUSE']).sum()
var.plot(kind='barh',stacked=False,grid=False)
plt.title("Causes based death rate",color="green",fontsize="25")
plt.xlabel("Number of Death rate",fontsize="20")
plt.ylabel("Causes",fontsize="20")
plt.show()

# %%
plt.rcParams["figure.figsize"]=(13,8)
data_frame_andhra = data[data["States"] == "TAMIL NADU"]
df_Andhdra =data_frame_andhra[["CAUSE","Male","Female"]]
df= df_Andhdra.groupby(['CAUSE']).sum()
df.plot(kind="barh",stacked=False,grid=False)
plt.title("Tamilnadu causes based death rate",color="green",fontsize="25")
plt.xlabel("Number of Death rate",fontsize="20")
plt.ylabel("Causes",fontsize="20")
plt.show()

# %%
data[data["Male"]==data["Male"].max()]
# Out:
#            States  Year        CAUSE  Male  Female  Total        Lat  \
# 2696  MAHARASHTRA  2012  Two Wheeler  4022     462   4484  19.250232
#
#            Long
# 2696  73.160175

# %%
#the highest number of male deaths occures at maharastra in the year of 2012 caused by two wheeler

# %%
data[data["Female"]==data["Female"].max()]
# Out:
#              States  Year          CAUSE  Male  Female  Total        Lat  \
# 4584  UTTAR PRADESH  2006  Car (Private)   562     653   1215  27.599981
#
#            Long
# 4584  78.050006

# %%
#the highest number of female deaths occures at uttra pradesh in the year of 2006 caused by car

# %%
data[data["Total"]==data["Total"].max()]
# Out:
#            States  Year        CAUSE  Male  Female  Total        Lat  \
# 2696  MAHARASHTRA  2012  Two Wheeler  4022     462   4484  19.250232
#
#            Long
# 2696  73.160175

# %%
#the highest number of deaths occures at maharastra in the year of 2012 caused by two wheeler

# %% [markdown]
# # conclusions

# %%
# From 2001 to 2012 the death rate is increased rapidly
# Every year number of female death rate is lower than the male death rate
# Most of the accidents are occurs at the Andhra Pradesh.So this government must avoid the accident by introducing
# the new rules
# Most of the accidents are occurs by the two-wheeler and lorry. So these vehicle drivers are must drive carefully
